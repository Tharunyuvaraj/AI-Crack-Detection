# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from os import listdir
import glob
from PIL import Image
import cv2
from random import randrange
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, MaxPool2D, Conv2DTranspose, Concatenate, Input
from tensorflow.keras.models import Model

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
ori_images = 'DATASET/TRAIN/ORIGINAL'
mask_images = 'DATASET/TRAIN/MASKS'

# %%
def load_data(dataset_path, split=0.2):
    images = [f for f in glob.glob(ori_images + "**/*.jpg", recursive=True)]
    masks = [f for f in glob.glob(mask_images + "**/*.jpg", recursive=True)]

    test_size = int(len(images) * split)

    train_x, test_x = train_test_split(images, test_size=test_size, random_state=42)
    train_y, test_y = train_test_split(masks, test_size=test_size, random_state=42)

    return (train_x, train_y), (test_x, test_y)

# %%
def read_image(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_COLOR)  
    x = cv2.resize(x, (128, 128))
    x = x/255.0
    x = x.astype(np.float32)
    return x

# %%
def read_mask(path):
    path = path.decode()
    x = cv2.imread(path, cv2.IMREAD_GRAYSCALE)  
    x = cv2.resize(x, (128, 128))
    x = x/255.0
    x = x.astype(np.float32)                    
    x = np.expand_dims(x, axis=-1)              
    return x

# %%
def tf_parse(x, y):
    def _parse(x, y):
        x = read_image(x)
        y = read_mask(y)
        return x, y

    x, y = tf.numpy_function(_parse, [x, y], [tf.float32, tf.float32])
    x.set_shape([128, 128, 3])
    y.set_shape([128, 128, 1])
    return x, y

def tf_dataset(X, Y, batch):
    dataset = tf.data.Dataset.from_tensor_slices((X, Y))
    dataset = dataset.map(tf_parse)
    dataset = dataset.batch(batch)
    dataset = dataset.prefetch(10)
    return dataset

# %%
dataset_path = "Dataset"
(train_x, train_y), (test_x, test_y) = load_data(dataset_path)

print(f"Train: {len(train_x)} - {len(train_y)}")
print(f"Test: {len(test_x)} - {len(test_y)}")
# Out:
# Train: 120 - 120
# Test: 30 - 30

# %%
batch = 4
train_dataset = tf_dataset(train_x, train_y, batch)
valid_dataset = tf_dataset(test_x, test_y, batch)

# %%
def conv_block(inputs, num_filters):
    x = Conv2D(num_filters, 3, padding="same")(inputs)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    x = Conv2D(num_filters, 3, padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    return x

def encoder_block(inputs, num_filters):
    x = conv_block(inputs, num_filters)
    p = MaxPool2D((2, 2))(x)
    return x, p

def decoder_block(inputs, skip_features, num_filters):
    x = Conv2DTranspose(num_filters, (2, 2), strides=2, padding="same")(inputs)
    x = Concatenate()([x, skip_features])
    x = conv_block(x, num_filters)
    return x

def build_unet(input_shape):
    inputs = Input(input_shape)

    """ Encoder """
    s1, p1 = encoder_block(inputs, 64)
    s2, p2 = encoder_block(p1, 128)
    s3, p3 = encoder_block(p2, 256)
    s4, p4 = encoder_block(p3, 512)

    """ Bridge """
    b1 = conv_block(p4, 1024)

    """ Decoder """
    d1 = decoder_block(b1, s4, 512)
    d2 = decoder_block(d1, s3, 256)
    d3 = decoder_block(d2, s2, 128)
    d4 = decoder_block(d3, s1, 64)

    """ Outputs """
    outputs = Conv2D(1, 1, padding="same", activation="sigmoid")(d4)

    """ Model """
    model = Model(inputs, outputs)
    return model

# %%
model = build_unet((128, 128, 3))
model.compile(loss="binary_crossentropy", optimizer=Adam(), metrics=['accuracy'])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 128, 128, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 128, 128, 64  1792        ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 128, 128, 64  256        ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 128, 128, 64  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 128, 128, 64  36928       ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 128, 128, 64  256        ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 128, 128, 64  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 64, 64, 64)   0           ['activation_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 64, 64, 128)  73856       ['max_pooling2d[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 64, 64, 128)  512        ['conv2d_2[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 64, 64, 128)  0           ['batch_normalization_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 64, 64, 128)  147584      ['activation_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 64, 64, 128)  512        ['conv2d_3[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 64, 64, 128)  0           ['batch_normalization_3[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 128)  0          ['activation_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 32, 32, 256)  295168      ['max_pooling2d_1[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 32, 32, 256)  1024       ['conv2d_4[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 32, 32, 256)  0           ['batch_normalization_4[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 32, 32, 256)  590080      ['activation_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 32, 32, 256)  1024       ['conv2d_5[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 32, 32, 256)  0           ['batch_normalization_5[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 256)  0          ['activation_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 16, 16, 512)  1180160     ['max_pooling2d_2[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 16, 16, 512)  2048       ['conv2d_6[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 16, 16, 512)  0           ['batch_normalization_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 16, 16, 512)  2359808     ['activation_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 16, 16, 512)  2048       ['conv2d_7[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 16, 16, 512)  0           ['batch_normalization_7[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 512)   0           ['activation_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 8, 8, 1024)   4719616     ['max_pooling2d_3[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 8, 8, 1024)  4096        ['conv2d_8[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 8, 8, 1024)   0           ['batch_normalization_8[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 8, 8, 1024)   9438208     ['activation_8[0][0]']
#  batch_normalization_9 (BatchNo  (None, 8, 8, 1024)  4096        ['conv2d_9[0][0]']
#  rmalization)
#
#  activation_9 (Activation)      (None, 8, 8, 1024)   0           ['batch_normalization_9[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 16, 16, 512)  2097664    ['activation_9[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 16, 16, 1024  0           ['conv2d_transpose[0][0]',
#                                 )                                 'activation_7[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 16, 16, 512)  4719104     ['concatenate[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 16, 16, 512)  2048       ['conv2d_10[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 16, 16, 512)  0           ['batch_normalization_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 16, 16, 512)  2359808     ['activation_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 16, 16, 512)  2048       ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 16, 16, 512)  0           ['batch_normalization_11[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 32, 32, 256)  524544     ['activation_11[0][0]']
#  spose)
#
#  concatenate_1 (Concatenate)    (None, 32, 32, 512)  0           ['conv2d_transpose_1[0][0]',
#                                                                   'activation_5[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 32, 32, 256)  1179904     ['concatenate_1[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 32, 32, 256)  1024       ['conv2d_12[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 32, 32, 256)  0           ['batch_normalization_12[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 32, 32, 256)  590080      ['activation_12[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 32, 32, 256)  1024       ['conv2d_13[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 32, 32, 256)  0           ['batch_normalization_13[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 64, 64, 128)  131200     ['activation_13[0][0]']
#  spose)
#
#  concatenate_2 (Concatenate)    (None, 64, 64, 256)  0           ['conv2d_transpose_2[0][0]',
#                                                                   'activation_3[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 64, 64, 128)  295040      ['concatenate_2[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 64, 64, 128)  512        ['conv2d_14[0][0]']
#  ormalization)
#
#  activation_14 (Activation)     (None, 64, 64, 128)  0           ['batch_normalization_14[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 64, 64, 128)  147584      ['activation_14[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 64, 64, 128)  512        ['conv2d_15[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 64, 64, 128)  0           ['batch_normalization_15[0][0]']
#
#  conv2d_transpose_3 (Conv2DTran  (None, 128, 128, 64  32832      ['activation_15[0][0]']
#  spose)                         )
#
#  concatenate_3 (Concatenate)    (None, 128, 128, 12  0           ['conv2d_transpose_3[0][0]',
#                                 8)                                'activation_1[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 128, 128, 64  73792       ['concatenate_3[0][0]']
#                                 )
#
#  batch_normalization_16 (BatchN  (None, 128, 128, 64  256        ['conv2d_16[0][0]']
#  ormalization)                  )
#
#  activation_16 (Activation)     (None, 128, 128, 64  0           ['batch_normalization_16[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 128, 128, 64  36928       ['activation_16[0][0]']
#                                 )
#  batch_normalization_17 (BatchN  (None, 128, 128, 64  256        ['conv2d_17[0][0]']
#  ormalization)                  )
#
#  activation_17 (Activation)     (None, 128, 128, 64  0           ['batch_normalization_17[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 128, 128, 1)  65          ['activation_17[0][0]']
#
# ==================================================================================================
# Total params: 31,055,297
# Trainable params: 31,043,521
# Non-trainable params: 11,776
# __________________________________________________________________________________________________

# %%
model_path = 'DEEPCRACK.h5'
callbacks = [
        ModelCheckpoint(model_path, verbose=1, save_best_only=True, monitor = 'accuracy')
    ]

# %%
batch_size = 32
num_epoch = 20

# %%
model.fit(
    train_dataset.repeat(),
    epochs=num_epoch,
    validation_data=valid_dataset.repeat(),
    steps_per_epoch=len(train_x)//batch_size,
    validation_steps=len(test_x)//batch_size,
    callbacks=callbacks
)
# Out:
# Epoch 1/20
# 3/3 [==============================] - ETA: 0s - loss: 0.6006 - accuracy: 0.6756
# Epoch 1: accuracy improved from -inf to 0.67557, saving model to DEEPCRACK.h5
# 3/3 [==============================] - 31s 7s/step - loss: 0.6006 - accuracy: 0.6756
# Epoch 2/20
# 3/3 [==============================] - ETA: 0s - loss: 0.4507 - accuracy: 0.9062
# Epoch 2: accuracy improved from 0.67557 to 0.90624, saving model to DEEPCRACK.h5
# 3/3 [==============================] - 18s 7s/step - loss: 0.4507 - accuracy: 0.9062
# Epoch 3/20
# 3/3 [==============================] - ETA: 0s - loss: 0.3199 - accuracy: 0.9403
# Epoch 3: accuracy improved from 0.90624 to 0.94030, saving model to DEEPCRACK.h5
# 3/3 [==============================] - 27s 11s/step - loss: 0.3199 - accuracy: 0.9403
# Epoch 4/20
# 3/3 [==============================] - ETA: 0s - loss: 0.2385 - accuracy: 0.9466
# Epoch 4: accuracy improved from 0.94030 to 0.94661, saving model to DEEPCRACK.h5
# 3/3 [==============================] - 26s 11s/step - loss: 0.2385 - accuracy: 0.9466
# Epoch 5/20
# 3/3 [==============================] - ETA: 0s - loss: 0.2267 - accuracy: 0.9526
# Epoch 5: accuracy improved from 0.94661 to 0.95256, saving model to DEEPCRACK.h5
# 3/3 [==============================] - 26s 11s/step - loss: 0.2267 - accuracy: 0.9526
# Epoch 6/20
# 3/3 [==============================] - ETA: 0s - loss: 0.1843 - accuracy: 0.9528
# Epoch 6: accuracy improved from 0.95256 to 0.95275, saving model to DEEPCRACK.h5
# 3/3 [==============================] - 24s 10s/step - loss: 0.1843 - accuracy: 0.9528
# Epoch 7/20
# 3/3 [==============================] - ETA: 0s - loss: 0.1615 - accuracy: 0.9494
# Epoch 7: accuracy did not improve from 0.95275
# 3/3 [==============================] - 16s 5s/step - loss: 0.1615 - accuracy: 0.9494
# Epoch 8/20
# 3/3 [==============================] - ETA: 0s - loss: 0.2089 - accuracy: 0.9451
# Epoch 8: accuracy did not improve from 0.95275
# 3/3 [==============================] - 17s 6s/step - loss: 0.2089 - accuracy: 0.9451
# Epoch 9/20
# 3/3 [==============================] - ETA: 0s - loss: 0.1299 - accuracy: 0.9533
# Epoch 9: accuracy improved from 0.95275 to 0.95328, saving model to DEEPCRACK.h5
# 3/3 [==============================] - 18s 7s/step - loss: 0.1299 - accuracy: 0.9533
# Epoch 10/20
# 3/3 [==============================] - ETA: 0s - loss: 0.1304 - accuracy: 0.9468
# Epoch 10: accuracy did not improve from 0.95328
# 3/3 [==============================] - 16s 6s/step - loss: 0.1304 - accuracy: 0.9468
# Epoch 11/20
# 3/3 [==============================] - ETA: 0s - loss: 0.1467 - accuracy: 0.9438
# Epoch 11: accuracy did not improve from 0.95328
# 3/3 [==============================] - 17s 6s/step - loss: 0.1467 - accuracy: 0.9438
# Epoch 12/20
# 3/3 [==============================] - ETA: 0s - loss: 0.1205 - accuracy: 0.9551
# Epoch 12: accuracy improved from 0.95328 to 0.95512, saving model to DEEPCRACK.h5
# 3/3 [==============================] - 21s 8s/step - loss: 0.1205 - accuracy: 0.9551
# Epoch 13/20
# 3/3 [==============================] - ETA: 0s - loss: 0.1188 - accuracy: 0.9463
# Epoch 13: accuracy did not improve from 0.95512
# 3/3 [==============================] - 17s 6s/step - loss: 0.1188 - accuracy: 0.9463
# Epoch 14/20
# 3/3 [==============================] - ETA: 0s - loss: 0.1088 - accuracy: 0.9543
# Epoch 14: accuracy did not improve from 0.95512
# 3/3 [==============================] - 16s 5s/step - loss: 0.1088 - accuracy: 0.9543
# Epoch 15/20
# 3/3 [==============================] - ETA: 0s - loss: 0.1048 - accuracy: 0.9562
# Epoch 15: accuracy improved from 0.95512 to 0.95619, saving model to DEEPCRACK.h5
# 3/3 [==============================] - 20s 8s/step - loss: 0.1048 - accuracy: 0.9562
# Epoch 16/20
# 3/3 [==============================] - ETA: 0s - loss: 0.0994 - accuracy: 0.9529
# Epoch 16: accuracy did not improve from 0.95619
# 3/3 [==============================] - 16s 5s/step - loss: 0.0994 - accuracy: 0.9529
# Epoch 17/20
# 3/3 [==============================] - ETA: 0s - loss: 0.0884 - accuracy: 0.9534
# Epoch 17: accuracy did not improve from 0.95619
# 3/3 [==============================] - 9s 3s/step - loss: 0.0884 - accuracy: 0.9534
# Epoch 18/20
# 3/3 [==============================] - ETA: 0s - loss: 0.1230 - accuracy: 0.9501
# Epoch 18: accuracy did not improve from 0.95619
# 3/3 [==============================] - 9s 3s/step - loss: 0.1230 - accuracy: 0.9501
# Epoch 19/20
# 3/3 [==============================] - ETA: 0s - loss: 0.0776 - accuracy: 0.9548
# Epoch 19: accuracy did not improve from 0.95619
# 3/3 [==============================] - 9s 3s/step - loss: 0.0776 - accuracy: 0.9548
# Epoch 20/20
# 3/3 [==============================] - ETA: 0s - loss: 0.0764 - accuracy: 0.9497
# Epoch 20: accuracy did not improve from 0.95619
# 3/3 [==============================] - 8s 3s/step - loss: 0.0764 - accuracy: 0.9497

# %%
def graph():
    #Plot training & validation accuracy values
    plt.plot(model.history.history['accuracy'])
    plt.plot(model.history.history['loss'])
    plt.title('Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Accuracy', 'loss'], loc='upper left')
    plt.show()
graph()
