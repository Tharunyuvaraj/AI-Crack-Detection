# %%
import nltk
nltk.download('punkt')
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import json
import pickle

import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers import SGD   
import random

words=[]
classes = []
documents = []
ignore_words = ['?', '!']
data_file = open('intents.json').read()
intents = json.loads(data_file)


for intent in intents['intents']:
    for pattern in intent['patterns']:

        # take each word and tokenize it
        w = nltk.word_tokenize(pattern)
        words.extend(w)
        # adding documents
        documents.append((w, intent['tag']))

        # adding classes to our class list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))

classes = sorted(list(set(classes)))

print (len(documents), "documents")

print (len(classes), "classes", classes)

print (len(words), "unique lemmatized words", words)


pickle.dump(words,open('wordsC.pkl','wb'))
pickle.dump(classes,open('classesC.pkl','wb'))

# initializing training data
training = []
output_empty = [0] * len(classes)
for doc in documents:
    # initializing bag of words
    bag = []
    # list of tokenized words for the pattern
    pattern_words = doc[0]
    # lemmatize each word - create base word, in attempt to represent related words
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    # create our bag of words array with 1, if word match found in current pattern
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)

    # output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1

    training.append([bag, output_row])
# shuffle our features and turn into np.array
random.shuffle(training)
#training = np.array(training)
# create train and test lists. X - patterns, Y - intents
train_x = [item[0] for item in training]
train_y = [item[1] for item in training]
print("Training data created")


# Create model - 3 layers. First layer 128 neurons, second layer 64 neurons and 3rd output layer contains number of neurons
# equal to number of intents to predict output intent with softmax
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

# Compile model. Stochastic gradient descent with Nesterov accelerated gradient gives good results for this model
sgd = SGD(lr=0.01, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

#fitting and saving the model
hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save('chatbot_modelC.h5', hist)

print("model created")
# Out:
# [nltk_data] Downloading package punkt to C:\Users\SPIRO-
# [nltk_data]     PYTHON1\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to C:\Users\SPIRO-
# [nltk_data]     PYTHON1\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# 340 documents
# 61 classes ['bricks', 'bricks_usage', 'building_codes', 'building_cracks', 'cement', 'cement_uses', 'concrete_curing', 'concrete_mixer_capacity', 'concrete_strength', 'construction_cost', 'construction_costs', 'construction_industry_growth', 'construction_materials', 'construction_project_management', 'construction_quality_control', 'construction_safety', 'construction_schedule', 'construction_technology', 'construction_waste', 'drywall_repair', 'energy_efficiency', 'flood_damage', 'flooring_materials', 'foundation_cracks', 'foundation_materials', 'foundation_repair', 'glass_usage', 'gravel_usage', 'greeting', 'home_improvement', 'home_security', 'hvac_maintenance', 'insulation', 'insulation_materials', 'landscaping', 'masonry_cracks', 'mold_removal', 'paint_consumption', 'painting', 'pest_control', 'pest_inspection', 'plumbing_issues', 'roof_damage', 'roof_leak', 'roof_maintenance', 'roof_materials', 'sand', 'sand_and_cement_mixture', 'sand_usage', 'scaffolding_usage', 'sewage_system', 'site_safety', 'steel_reinforcement', 'steel_usage', 'storm_damage', 'structural_integrity', 'timber_usage', 'ventilation', 'wall_cracks', 'waterproofing', 'waterproofing_materials']
# 390 unique lemmatized words ["'s", '(', ')', '3d', 'a', 'accident', 'address', 'advancement', 'affect', 'aggregate', 'ai', 'amount', 'an', 'and', 'annually', 'appliance', 'are', 'ass', 'attempt', 'average', 'avoid', 'avoided', 'basement', 'be', 'beam', 'before', 'benefit', 'best', 'between', 'bill', 'bim', 'blockage', 'break-in', 'brick', 'budget', 'budgeting', 'building', 'buying', 'by', 'calculate', 'calculated', 'call', 'camera', 'can', 'capacity', 'cause', 'cement', 'challenge', 'change', 'choice', 'choose', 'choosing', 'clay', 'code', 'column', 'commercial', 'common', 'commonly', 'compliance', 'component', 'compressive', 'concrete', 'condition', 'considered', 'construction', 'consumed', 'consumption', 'contribute', 'control', 'cost', 'coverage', 'covered', 'crack', 'create', 'cubic', 'cured', 'curing', 'current', 'damage', 'damaged', 'day', 'delay', 'develop', 'development', 'difference', 'different', 'do', 'doe', 'door', 'drone', 'drywall', 'durable', 'during', 'easy', 'economic', 'effect', 'effective', 'efficiency', 'electricity', 'eliminate', 'emerging', 'energy', 'energy-efficient', 'ensure', 'environmental', 'equipment', 'estimated', 'expect', 'exposure', 'extend', 'exterior', 'extreme', 'factor', 'faucet', 'filter', 'finish', 'fix', 'flood', 'flood-damaged', 'flooded', 'flooring', 'fluctuate', 'foam', 'foot', 'for', 'found', 'foundation', 'from', 'garden', 'generated', 'get', 'glass', 'good', 'gravel', 'greeting', 'growth', 'handle', 'happens', 'have', 'hazard', 'health', 'heating', 'heavy', 'height', 'hello', 'hey', 'hi', 'high-rise', 'hire', 'hole', 'home', 'house', 'household', 'how', 'hvac', 'i', 'idea', 'if', 'impact', 'importance', 'important', 'improve', 'improvement', 'in', 'increase', 'indication', 'industry', 'infestation', 'inflation', 'influence', 'information', 'infrastructure', 'inspect', 'inspection', 'install', 'insulation', 'insurance', 'integrity', 'is', 'issue', 'it', 'key', 'know', 'labor', 'landscaping', 'large', 'large-scale', 'last', 'latest', 'lawn', 'lead', 'leak', 'leaking', 'leaky', 'legal', 'lifespan', 'long', 'long-term', 'low', 'low-maintenance', 'main', 'maintain', 'maintenance', 'make', 'management', 'manager', 'many', 'masonry', 'material', 'measure', 'measured', 'mechanical', 'meter', 'method', 'milestone', 'minimized', 'mix', 'mixer', 'mixture', 'modeling', 'mold', 'more', 'mortar', 'most', 'much', 'my', 'natural', 'need', 'needed', 'new', 'not', 'number', 'of', 'often', 'old', 'on', 'opc', 'option', 'or', 'over', 'overall', 'paint', 'painted', 'painting', 'passive', 'patch', 'per', 'percentage', 'personal', 'pest', 'pipe', 'place', 'plant', 'plaster', 'play', 'plumber', 'plumbing', 'poor', 'ppc', 'ppe', 'prepare', 'pressure', 'prevent', 'prevented', 'price', 'printing', 'problem', 'produce', 'produced', 'production', 'professional', 'project', 'proper', 'properly', 'property', 'protective', 'purpose', 'quality', 'quantity', 'rate', 'ratio', 'recycled', 'reduce', 'reduced', 'region', 'regular', 'regulation', 'reinforcement', 'removal', 'remove', 'renovation', 'rental', 'repair', 'replace', 'required', 'requirement', 'residential', 'responsibility', 'rid', 'right', 'risk', 'road', 'role', 'roof', 'roofing', 'room', 'safety', 'sand', 'scaffolding', 'schedule', 'scheduling', 'seam', 'secure', 'security', 'seeing', 'seepage', 'serious', 'sewage', 'should', 'sign', 'significance', 'simple', 'site', 'size', 'software', 'soil', 'solar', 'some', 'spray', 'square', 'stability', 'standard', 'start', 'steel', 'store', 'stored', 'storm', 'streak', 'strength', 'structural', 'structure', 'surface', 'sustainability', 'sustainable', 'system', 'technological', 'termite', 'testing', 'the', 'there', 'tile', 'timber', 'timeline', 'to', 'tool', 'treat', 'trend', 'truck-mounted', 'type', 'typical', 'usage', 'use', 'used', 'using', 'value', 'vary', 'ventilation', 'violation', 'wall', 'waste', 'water', 'waterproof', 'waterproofing', 'way', 'weak', 'weather', 'what', 'when', 'which', 'why', 'window', 'wint ...
# Training data created
# F:\SOFTWARE\ANACONDA\envs\face\lib\site-packages\keras\optimizers\optimizer_v2\gradient_descent.py:108: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)
# Epoch 1/200
# 68/68 [==============================] - 1s 2ms/step - loss: 4.1310 - accuracy: 0.0206
# Epoch 2/200
# 68/68 [==============================] - 0s 2ms/step - loss: 4.0879 - accuracy: 0.0206
# Epoch 3/200
# 68/68 [==============================] - 0s 2ms/step - loss: 4.0207 - accuracy: 0.0559
# Epoch 4/200
# 68/68 [==============================] - 0s 2ms/step - loss: 3.9582 - accuracy: 0.0824
# Epoch 5/200
# 68/68 [==============================] - 0s 3ms/step - loss: 3.8072 - accuracy: 0.0794
# Epoch 6/200
# 68/68 [==============================] - 0s 3ms/step - loss: 3.6576 - accuracy: 0.1294
# Epoch 7/200
# 68/68 [==============================] - 0s 2ms/step - loss: 3.4784 - accuracy: 0.1206
# Epoch 8/200
# 68/68 [==============================] - 0s 2ms/step - loss: 3.2976 - accuracy: 0.2059
# Epoch 9/200
# 68/68 [==============================] - 0s 3ms/step - loss: 3.1117 - accuracy: 0.2000
# Epoch 10/200
# 68/68 [==============================] - 0s 3ms/step - loss: 2.8381 - accuracy: 0.2647
# Epoch 11/200
# 68/68 [==============================] - 0s 3ms/step - loss: 2.6363 - accuracy: 0.3088
# Epoch 12/200
# 68/68 [==============================] - 0s 2ms/step - loss: 2.4352 - accuracy: 0.3324
# Epoch 13/200
# 68/68 [==============================] - 0s 3ms/step - loss: 2.1439 - accuracy: 0.3912
# Epoch 14/200
# 68/68 [==============================] - 0s 3ms/step - loss: 2.2325 - accuracy: 0.3912
# Epoch 15/200
# 68/68 [==============================] - 0s 4ms/step - loss: 1.8791 - accuracy: 0.4471
# Epoch 16/200
# 68/68 [==============================] - 0s 2ms/step - loss: 1.7626 - accuracy: 0.4676
# Epoch 17/200
# 68/68 [==============================] - 0s 2ms/step - loss: 1.6795 - accuracy: 0.5029
# Epoch 18/200
# 68/68 [==============================] - 0s 2ms/step - loss: 1.6376 - accuracy: 0.5206
# Epoch 19/200
# 68/68 [==============================] - 0s 2ms/step - loss: 1.5526 - accuracy: 0.5559
# Epoch 20/200
# 68/68 [==============================] - 0s 2ms/step - loss: 1.4063 - accuracy: 0.5706
# Epoch 21/200
# 68/68 [==============================] - 0s 2ms/step - loss: 1.3467 - accuracy: 0.5941
# Epoch 22/200
# 68/68 [==============================] - 0s 3ms/step - loss: 1.2466 - accuracy: 0.6118
# Epoch 23/200
# 68/68 [==============================] - 0s 3ms/step - loss: 1.2986 - accuracy: 0.6176
# Epoch 24/200
# 68/68 [==============================] - 0s 2ms/step - loss: 1.3095 - accuracy: 0.6059
# Epoch 25/200
# 68/68 [==============================] - 0s 2ms/step - loss: 1.1094 - accuracy: 0.6618
# Epoch 26/200
# 68/68 [==============================] - 0s 2ms/step - loss: 1.2120 - accuracy: 0.6500
# Epoch 27/200
# 68/68 [==============================] - 0s 2ms/step - loss: 1.2049 - accuracy: 0.6324
# Epoch 28/200
# 68/68 [==============================] - 0s 3ms/step - loss: 1.0921 - accuracy: 0.6294
# Epoch 29/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.9925 - accuracy: 0.6882
# Epoch 30/200
# 68/68 [==============================] - 0s 3ms/step - loss: 1.0549 - accuracy: 0.6765
# Epoch 31/200
# 68/68 [==============================] - 0s 3ms/step - loss: 1.0222 - accuracy: 0.7000
# Epoch 32/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.8551 - accuracy: 0.7441
# Epoch 33/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.9006 - accuracy: 0.7147
# Epoch 34/200
# 68/68 [==============================] - 0s 2ms/step - loss: 1.0043 - accuracy: 0.6676
# Epoch 35/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.8614 - accuracy: 0.7176
# Epoch 36/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.8292 - accuracy: 0.7206
# Epoch 37/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.8881 - accuracy: 0.7324
# Epoch 38/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.7701 - accuracy: 0.7735
# Epoch 39/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.8847 - accuracy: 0.7235
# Epoch 40/200
# 68/68 [==============================] - 0s 3ms/step - loss: 0.8367 - accuracy: 0.7706
# Epoch 41/200
# 68/68 [==============================] - 0s 3ms/step - loss: 0.8530 - accuracy: 0.7235
# Epoch 42/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.7893 - accuracy: 0.7588
# Epoch 43/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.8057 - accuracy: 0.7412
# Epoch 44/200
# 68/68 [==============================] - 0s 3ms/step - loss: 0.7030 - accuracy: 0.7647
# Epoch 45/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.6579 - accuracy: 0.7912
# Epoch 46/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.7274 - accuracy: 0.7324
# Epoch 47/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.6950 - accuracy: 0.8029
# Epoch 48/200
# 68/68 [==============================] - 0s 3ms/step - loss: 0.7313 - accuracy: 0.7588
# Epoch 49/200
# 68/68 [==============================] - 0s 3ms/step - loss: 0.7560 - accuracy: 0.7471
# Epoch 50/200
# 68/68 [==============================] - 0s 3ms/step - loss: 0.6312 - accuracy: 0.7882
# Epoch 51/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.6293 - accuracy: 0.7971
# Epoch 52/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.7017 - accuracy: 0.7676
# Epoch 53/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.6117 - accuracy: 0.7971
# Epoch 54/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.6433 - accuracy: 0.7824
# Epoch 55/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.6421 - accuracy: 0.7735
# Epoch 56/200
# 68/68 [==============================] - 0s 4ms/step - loss: 0.5733 - accuracy: 0.8176
# Epoch 57/200
# 68/68 [==============================] - 0s 4ms/step - loss: 0.6568 - accuracy: 0.8000
# Epoch 58/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.5990 - accuracy: 0.8147
# Epoch 59/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.7145 - accuracy: 0.7794
# Epoch 60/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.5506 - accuracy: 0.8382
# Epoch 61/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.6624 - accuracy: 0.7794
# Epoch 62/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.7722 - accuracy: 0.7676
# Epoch 63/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.5814 - accuracy: 0.8265
# Epoch 64/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.6685 - accuracy: 0.8059
# Epoch 65/200
# 68/68 [==============================] - 0s 3ms/step - loss: 0.6104 - accuracy: 0.7941
# Epoch 66/200
# 68/68 [==============================] - 0s 3ms/step - loss: 0.5598 - accuracy: 0.8147
# Epoch 67/200
# 68/68 [==============================] - 0s 3ms/step - loss: 0.5410 - accuracy: 0.8235
# Epoch 68/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.5864 - accuracy: 0.8206
# Epoch 69/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.4995 - accuracy: 0.8353
# Epoch 70/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.5476 - accuracy: 0.8294
# Epoch 71/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.5138 - accuracy: 0.8088
# Epoch 72/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.5706 - accuracy: 0.8088
# Epoch 73/200
# 68/68 [==============================] - 0s 3ms/step - loss: 0.6508 - accuracy: 0.7765
# Epoch 74/200
# 68/68 [==============================] - 0s 3ms/step - loss: 0.4950 - accuracy: 0.8147
# Epoch 75/200
# 68/68 [==============================] - 0s 3ms/step - loss: 0.5525 - accuracy: 0.8118
# Epoch 76/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.5844 - accuracy: 0.8118
# Epoch 77/200
# 68/68 [==============================] - 0s 4ms/step - loss: 0.5438 - accuracy: 0.8118
# Epoch 78/200
# 68/68 [==============================] - 0s 4ms/step - loss: 0.5868 - accuracy: 0.8265
# Epoch 79/200
# 68/68 [==============================] - 0s 3ms/step - loss: 0.5800 - accuracy: 0.8088
# Epoch 80/200
# 68/68 [==============================] - 0s 3ms/step - loss: 0.5353 - accuracy: 0.8353
# Epoch 81/200
# 68/68 [==============================] - 0s 3ms/step - loss: 0.6304 - accuracy: 0.8147
# Epoch 82/200
# 68/68 [==============================] - 0s 3ms/step - loss: 0.6078 - accuracy: 0.7824
# Epoch 83/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.4340 - accuracy: 0.8500
# Epoch 84/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.6721 - accuracy: 0.8176
# Epoch 85/200
# 68/68 [==============================] - 0s 3ms/step - loss: 0.5171 - accuracy: 0.8265
# Epoch 86/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.5611 - accuracy: 0.8206
# Epoch 87/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.5050 - accuracy: 0.8529
# Epoch 88/200
# 68/68 [==============================] - 0s 3ms/step - loss: 0.5103 - accuracy: 0.8471
# Epoch 89/200
# 68/68 [==============================] - 0s 3ms/step - loss: 0.5328 - accuracy: 0.8147
# Epoch 90/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.5016 - accuracy: 0.8559
# Epoch 91/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.5217 - accuracy: 0.8235
# Epoch 92/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.5162 - accuracy: 0.8265
# Epoch 93/200
# 68/68 [==============================] - 0s 3ms/step - loss: 0.6852 - accuracy: 0.8088
# Epoch 94/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.5382 - accuracy: 0.8471
# Epoch 95/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.5508 - accuracy: 0.8441
# Epoch 96/200
# 68/68 [==============================] - 0s 3ms/step - loss: 0.4361 - accuracy: 0.8471
# Epoch 97/200
# 68/68 [==============================] - 0s 3ms/step - loss: 0.4249 - accuracy: 0.8529
# Epoch 98/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.4326 - accuracy: 0.8353
# Epoch 99/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.3887 - accuracy: 0.8912
# Epoch 100/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.4145 - accuracy: 0.8647
# Epoch 101/200
# 68/68 [==============================] - 0s 3ms/step - loss: 0.4795 - accuracy: 0.8559
# Epoch 102/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.4164 - accuracy: 0.8676
# Epoch 103/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.4828 - accuracy: 0.8353
# Epoch 104/200
# 68/68 [==============================] - 0s 3ms/step - loss: 0.3502 - accuracy: 0.8824
# Epoch 105/200
# 68/68 [==============================] - 0s 3ms/step - loss: 0.4656 - accuracy: 0.8382
# Epoch 106/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.4799 - accuracy: 0.8147
# Epoch 107/200
# 68/68 [==============================] - 0s 3ms/step - loss: 0.4753 - accuracy: 0.8412
# Epoch 108/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.4487 - accuracy: 0.8824
# Epoch 109/200
# 68/68 [==============================] - 0s 3ms/step - loss: 0.3293 - accuracy: 0.8912
# Epoch 110/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.4617 - accuracy: 0.8794
# Epoch 111/200
# 68/68 [==============================] - 0s 3ms/step - loss: 0.4576 - accuracy: 0.8676
# Epoch 112/200
# 68/68 [==============================] - 0s 3ms/step - loss: 0.4576 - accuracy: 0.8529
# Epoch 113/200
# 68/68 [==============================] - 0s 3ms/step - loss: 0.5116 - accuracy: 0.8206
# Epoch 114/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.5884 - accuracy: 0.8324
# Epoch 115/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.4198 - accuracy: 0.8559
# Epoch 116/200
# 68/68 [==============================] - 0s 3ms/step - loss: 0.4862 - accuracy: 0.8559
# Epoch 117/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.4070 - accuracy: 0.8676
# Epoch 118/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.2770 - accuracy: 0.9059
# Epoch 119/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.4983 - accuracy: 0.8471
# Epoch 120/200
# 68/68 [==============================] - 0s 3ms/step - loss: 0.4222 - accuracy: 0.8559
# Epoch 121/200
# 68/68 [==============================] - 0s 3ms/step - loss: 0.4696 - accuracy: 0.8588
# Epoch 122/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.4717 - accuracy: 0.8765
# Epoch 123/200
# 68/68 [==============================] - 0s 3ms/step - loss: 0.4338 - accuracy: 0.8735
# Epoch 124/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.4565 - accuracy: 0.8618
# Epoch 125/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.4620 - accuracy: 0.8765
# Epoch 126/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.5619 - accuracy: 0.8353
# Epoch 127/200
# 68/68 [==============================] - 0s 5ms/step - loss: 0.4730 - accuracy: 0.8471
# Epoch 128/200
# 68/68 [==============================] - 0s 5ms/step - loss: 0.4327 - accuracy: 0.8735
# Epoch 129/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.4038 - accuracy: 0.8794
# Epoch 130/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.5259 - accuracy: 0.8353
# Epoch 131/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.4397 - accuracy: 0.8588
# Epoch 132/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.4413 - accuracy: 0.8941
# Epoch 133/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.3820 - accuracy: 0.8912
# Epoch 134/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.3718 - accuracy: 0.8735
# Epoch 135/200
# 68/68 [==============================] - 0s 4ms/step - loss: 0.4741 - accuracy: 0.8706
# Epoch 136/200
# 68/68 [==============================] - 0s 3ms/step - loss: 0.4064 - accuracy: 0.8912
# Epoch 137/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.4302 - accuracy: 0.8706
# Epoch 138/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.4835 - accuracy: 0.8206
# Epoch 139/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.5222 - accuracy: 0.8206
# Epoch 140/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.4477 - accuracy: 0.8471
# Epoch 141/200
# 68/68 [==============================] - 0s 3ms/step - loss: 0.5605 - accuracy: 0.8412
# Epoch 142/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.3719 - accuracy: 0.8824
# Epoch 143/200
# 68/68 [==============================] - 0s 3ms/step - loss: 0.5732 - accuracy: 0.8176
# Epoch 144/200
# 68/68 [==============================] - 0s 3ms/step - loss: 0.4080 - accuracy: 0.8971
# Epoch 145/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.4633 - accuracy: 0.8647
# Epoch 146/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.4724 - accuracy: 0.8765
# Epoch 147/200
# 68/68 [==============================] - 0s 3ms/step - loss: 0.4391 - accuracy: 0.8471
# Epoch 148/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.4371 - accuracy: 0.8676
# Epoch 149/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.4112 - accuracy: 0.8559
# Epoch 150/200
# 68/68 [==============================] - 0s 3ms/step - loss: 0.3706 - accuracy: 0.8882
# Epoch 151/200
# 68/68 [==============================] - 0s 3ms/step - loss: 0.3589 - accuracy: 0.8971
# Epoch 152/200
# 68/68 [==============================] - 0s 4ms/step - loss: 0.4332 - accuracy: 0.8676
# Epoch 153/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.3649 - accuracy: 0.8647
# Epoch 154/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.4585 - accuracy: 0.8794
# Epoch 155/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.4865 - accuracy: 0.8618
# Epoch 156/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.5366 - accuracy: 0.8588
# Epoch 157/200
# 68/68 [==============================] - 0s 3ms/step - loss: 0.4693 - accuracy: 0.8559
# Epoch 158/200
# 68/68 [==============================] - 0s 3ms/step - loss: 0.5217 - accuracy: 0.8382
# Epoch 159/200
# 68/68 [==============================] - 0s 3ms/step - loss: 0.5103 - accuracy: 0.8559
# Epoch 160/200
# 68/68 [==============================] - 0s 3ms/step - loss: 0.4439 - accuracy: 0.8588
# Epoch 161/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.4581 - accuracy: 0.8618
# Epoch 162/200
# 68/68 [==============================] - 0s 3ms/step - loss: 0.4861 - accuracy: 0.8500
# Epoch 163/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.4382 - accuracy: 0.8706
# Epoch 164/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.3365 - accuracy: 0.8882
# Epoch 165/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.3347 - accuracy: 0.8971
# Epoch 166/200
# 68/68 [==============================] - 0s 3ms/step - loss: 0.4323 - accuracy: 0.8735
# Epoch 167/200
# 68/68 [==============================] - 0s 4ms/step - loss: 0.5358 - accuracy: 0.8265
# Epoch 168/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.5058 - accuracy: 0.8706
# Epoch 169/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.3706 - accuracy: 0.8971
# Epoch 170/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.5527 - accuracy: 0.8500
# Epoch 171/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.4955 - accuracy: 0.8471
# Epoch 172/200
# 68/68 [==============================] - 0s 3ms/step - loss: 0.4392 - accuracy: 0.8706
# Epoch 173/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.3956 - accuracy: 0.8794
# Epoch 174/200
# 68/68 [==============================] - 0s 3ms/step - loss: 0.4854 - accuracy: 0.8618
# Epoch 175/200
# 68/68 [==============================] - 0s 3ms/step - loss: 0.3999 - accuracy: 0.8794
# Epoch 176/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.4154 - accuracy: 0.8706
# Epoch 177/200
# 68/68 [==============================] - 0s 3ms/step - loss: 0.4015 - accuracy: 0.9000
# Epoch 178/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.3563 - accuracy: 0.8853
# Epoch 179/200
# 68/68 [==============================] - 0s 3ms/step - loss: 0.3370 - accuracy: 0.8882
# Epoch 180/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.4181 - accuracy: 0.8735
# Epoch 181/200
# 68/68 [==============================] - 0s 4ms/step - loss: 0.5173 - accuracy: 0.8588
# Epoch 182/200
# 68/68 [==============================] - 0s 4ms/step - loss: 0.3154 - accuracy: 0.9088
# Epoch 183/200
# 68/68 [==============================] - 0s 3ms/step - loss: 0.4189 - accuracy: 0.8794
# Epoch 184/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.4750 - accuracy: 0.8647
# Epoch 185/200
# 68/68 [==============================] - 0s 3ms/step - loss: 0.4524 - accuracy: 0.8735
# Epoch 186/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.4721 - accuracy: 0.8500
# Epoch 187/200
# 68/68 [==============================] - 0s 3ms/step - loss: 0.4034 - accuracy: 0.8824
# Epoch 188/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.3582 - accuracy: 0.8882
# Epoch 189/200
# 68/68 [==============================] - 0s 3ms/step - loss: 0.4424 - accuracy: 0.8765
# Epoch 190/200
# 68/68 [==============================] - 0s 3ms/step - loss: 0.4558 - accuracy: 0.9000
# Epoch 191/200
# 68/68 [==============================] - 0s 3ms/step - loss: 0.4187 - accuracy: 0.8676
# Epoch 192/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.6196 - accuracy: 0.8441
# Epoch 193/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.3975 - accuracy: 0.8794
# Epoch 194/200
# 68/68 [==============================] - 0s 2ms/step - loss: 0.3851 - accuracy: 0.8853
# Epoch 195/200
# 68/68 [==============================] - 0s 3ms/step - loss: 0.5128 - accuracy: 0.8647
# Epoch 196/200
# 68/68 [==============================] - 0s 3ms/step - loss: 0.4258 - accuracy: 0.8794
# Epoch 197/200
# 68/68 [==============================] - 0s 3ms/step - loss: 0.5075 - accuracy: 0.8588
# Epoch 198/200
# 68/68 [==============================] - 0s 3ms/step - loss: 0.5785 - accuracy: 0.8441
# Epoch 199/200
# 68/68 [==============================] - 0s 3ms/step - loss: 0.7106 - accuracy: 0.8176
# Epoch 200/200
# 68/68 [==============================] - 0s 3ms/step - loss: 0.5235 - accuracy: 0.8324
# model created

# %%
# !pip freeze > requirements.txt

# %%
# !python --version

# %%
#! pip install -r requirements.txt
# pip install --upgrade googletrans==4.0.0-rc1
# pip install translate
